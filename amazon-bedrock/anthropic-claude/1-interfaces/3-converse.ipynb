# %%
import boto3
import json

client = boto3.client('bedrock-runtime')

model_id = "anthropic.claude-3-haiku-20240307-v1:0"

messages = [
    {
        "role": "user",
        "content": [
            {
                "text": "じゃがいもと豚肉を使った晩御飯のおかずのレシピを3つ、それぞれ200文字以内で教えてください。"
            }
        ]
    }
]

system = [
    {
        "text": "あなたは家庭料理の得意な料理人です。"
    }
]

inferenceConfig = {
    "maxTokens": 1000,
    "temperature": 0.7,
    "topP": 0.9
}

response = client.converse(
    modelId=model_id,
    system=system,
    messages=messages,
    inferenceConfig=inferenceConfig
)

print("===== Raw Response =====")
print(json.dumps(response, indent=2, ensure_ascii=False))

print("=====  Final output =====")
print(response["output"]["message"]["content"][0]["text"])
# Out:
# ===== Raw Response =====
# {
#   "ResponseMetadata": {
#     "RequestId": "fdf579c9-ae9a-4262-ab10-84cb48c70e31",
#     "HTTPStatusCode": 200,
#     "HTTPHeaders": {
#       "date": "Thu, 15 Jan 2026 12:55:00 GMT",
#       "content-type": "application/json",
#       "content-length": "1538",
#       "connection": "keep-alive",
#       "x-amzn-requestid": "fdf579c9-ae9a-4262-ab10-84cb48c70e31"
#     },
#     "RetryAttempts": 0
#   },
#   "output": {
#     "message": {
#       "role": "assistant",
#       "content": [
#         {
#           "text": "はい、じゃがいもと豚肉を使った晩御飯のおかずのレシピを3つご紹介します。\n\n1. じゃがいものそぼろ煮\nじゃがいもと豚ひき肉を使ったあっさりとしたそぼろ煮です。じゃがいもをさいの目に切り、豚ひき肉と一緒に炒めます。そこに玉ねぎ、にんじん、しょうゆ、みりん、砂糖を加えて煮込みます。野菜の甘みと豚肉のうまみがじゃがいもにしみ込んで、ご飯にもよく合う一品です。\n\n2. じゃがいものオーブン焼き\nじゃがいもを皮ごと1cm厚さのくし形に切り、オリーブオイル、塩コショウで味付けします。オーブンで20分ほど焼いて、最後にパルメザンチーズをかけて5分ほど焼き上げます。じゃがいもの中までしっかり焼き上がり、チーズのコクがアクセントになった美味しい一品です。\n\n3. じゃがいもと豚肉のしぐれ煮\nじゃがいもと豚肉を角切りにし、たまり醤油、みりん、砂糖、酒で煮込みます。じっくりと時間をかけて煮込むことで、じゃがいもの食感と豚肉のやわらかさが調和した、ご飯によく合う煮物になります。煮汁をよくからめて、ご飯のおかずにぴったりです。"
#         }
#       ]
#     }
#   },
#   "stopReason": "end_turn",
#   "usage": {
#     "inputTokens": 73,
#     "outputTokens": 504,
#     "totalTokens": 577
#   },
#   "metrics": {
#     "latencyMs": 4981
#   }
# }
# =====  Final output =====
# はい、じゃがいもと豚肉を使った晩御飯のおかずのレシピを3つご紹介します。
#
# 1. じゃがいものそぼろ煮
# じゃがいもと豚ひき肉を使ったあっさりとしたそぼろ煮です。じゃがいもをさいの目に切り、豚ひき肉と一緒に炒めます。そこに玉ねぎ、にんじん、しょうゆ、みりん、砂糖を加えて煮込みます。野菜の甘みと豚肉のうまみがじゃがいもにしみ込んで、ご飯にもよく合う一品です。
#
# 2. じゃがいものオーブン焼き
# じゃがいもを皮ごと1cm厚さのくし形に切り、オリーブオイル、塩コショウで味付けします。オーブンで20分ほど焼いて、最後にパルメザンチーズをかけて5分ほど焼き上げます。じゃがいもの中までしっかり焼き上がり、チーズのコクがアクセントになった美味しい一品です。
#
# 3. じゃがいもと豚肉のしぐれ煮
# じゃがいもと豚肉を角切りにし、たまり醤油、みりん、砂糖、酒で煮込みます。じっくりと時間をかけて煮込むことで、じゃがいもの食感と豚肉のやわらかさが調和した、ご飯によく合う煮物になります。煮汁をよくからめて、ご飯のおかずにぴったりです。
